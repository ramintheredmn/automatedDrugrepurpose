# %%
import pandas as pd
import chembl_webresource_client.new_client as nc
from rdkit import Chem
from rdkit.Chem import PandasTools
#import requests
#from bs4 import BeautifulSoup
#from chembletouni import chemble_to_uni
#from findpdb import get_pdb_with_best_resolution, get_all_pdb_entries
from webscraping import webScrape
#from openbabel import run_openbabel
#from prody import *
#from pylab import *
#import nglview as vw

# %%
tr = nc.new_client.target

# %%
query = tr.search('jak').only('target_chembl_id', 'organism', 'pref_name')
query_pd = pd.DataFrame.from_dict(query)
query_pd = query_pd[query_pd['target_chembl_id'].apply(lambda x: len(str(x)) == 10)]
query_pd
# Out:
#         organism                     pref_name target_chembl_id
# 2   Homo sapiens  Tyrosine-protein kinase JAK3       CHEMBL2148
# 7   Homo sapiens  Tyrosine-protein kinase JAK1       CHEMBL2835
# 8   Mus musculus  Tyrosine-protein kinase JAK1       CHEMBL2968
# 9   Homo sapiens  Tyrosine-protein kinase JAK2       CHEMBL2971
# 10  Mus musculus  Tyrosine-protein kinase JAK3       CHEMBL5250
# 21  Homo sapiens  Tyrosine-protein kinase TYK2       CHEMBL3553

# %%
target = query_pd.iloc[1]

# %%
target
# Out:
# organism                            Homo sapiens
# pref_name           Tyrosine-protein kinase JAK1
# target_chembl_id                      CHEMBL2835
# Name: 7, dtype: object

# %%
mych = str(target['target_chembl_id'])

# %%
uni = chemble_to_uni(mych)

# %%
best_pdb_id, best_length, best_resolution, chains = get_pdb_with_best_resolution(uni)

print(best_pdb_id,"| res : ", best_resolution, chains)
# Out:
# 5L04 | res :  2.1 D=1027-1042.

# %%
pdbs = get_all_pdb_entries(uni)
df = pd.DataFrame(pdbs)
sorted_df = df.sort_values(by=['length', 'num_chains', 'resolution'], ascending=[False, False, True])
sorted_df['resolution'] = sorted_df['resolution'].astype(str)
sorted_df['length'] = sorted_df['length'].astype(str)
sorted_df['num_chains'] = sorted_df['num_chains'].astype(str)
print(sorted_df.head(),sorted_df.dtypes)
# Out:
#    pdb_id method resolution length num_chains
# 23   5L04  X-ray        2.1    547          1
# 20   5IXI  X-ray       2.57    525          1
# 19   5IXD  X-ray       2.85    525          1
# 26   6BBU  X-ray       2.08    314          1
# 48   6W8L  X-ray       2.11    314          1 pdb_id        object
# method        object
# resolution    object
# length        object
# num_chains    object
# dtype: object

# %%
atoms, header = parsePDB(best_pdb_id, header=True)
list(header)
# Out:
# @> Connecting wwPDB FTP server RCSB PDB (USA).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/raminrafiee/Desktop/personal/projects/automatedDrugrepurpose/backend/modal.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/home/raminrafiee/Desktop/personal/projects/automatedDrugrepurpose/backend/modal.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> atoms, header = parsePDB(best_pdb_id, header=True)
#       <a href='vscode-notebook-cell:/home/raminrafiee/Desktop/personal/projects/automatedDrugrepurpose/backend/modal.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> list(header)
#
# File ~/Desktop/personal/projects/automatedDrugrepurpose/venv/lib/python3.10/site-packages/prody/proteins/pdbfile.py:124, in parsePDB(*pdb, **kwargs)
#     121         n_pdb = len(pdb)
#     123 if n_pdb == 1:
# --> 124     return _parsePDB(pdb[0], **kwargs)
#     125 else:
#     126     results = []
#
# File ~/Desktop/personal/projects/automatedDrugrepurpose/venv/lib/python3.10/site-packages/prody/proteins/pdbfile.py:210, in _parsePDB(pdb, **kwargs)
#     208     title = pdb
#     209     kwargs['title'] = title
# --> 210 filename = fetchPDB(pdb, **kwargs)
#     211 if filename is None:
#     212     try:
#
# File ~/Desktop/personal/projects/automatedDrugrepurpose/venv/lib/python3.10/site-packages/prody/proteins/localpdb.py:345, in fetchPDB(*pdb, **kwargs)
#     343 tryHTTP = False
#     344 try:
# --> 345     fns = fetchPDBviaFTP(*downloads, check=False, **kwargs)
#     346 except Exception as err:
#     347     tryHTTP = True
#
# File ~/Desktop/personal/projects/automatedDrugrepurpose/venv/lib/python3.10/site-packages/prody/proteins/wwpdb.py:200, in fetchPDBviaFTP(*pdb, **kwargs)
#     198     else:
#     199         ftp.cwd(pdb[1:3])
# --> 200     ftp.retrbinary('RETR ' + ftp_fn, data.append)
#     201 except Exception as error:
#     202     if ftp_fn in ftp.nlst():
#
# File /usr/lib/python3.10/ftplib.py:436, in FTP.retrbinary(self, cmd, callback, blocksize, rest)
#     422 """Retrieve data in binary mode.  A new port is created for you.
#     423
#     424 Args:
#    (...)
#     433   The response code.
#     434 """
#     435 self.voidcmd('TYPE I')
# --> 436 with self.transfercmd(cmd, rest) as conn:
#     437     while 1:
#     438         data = conn.recv(blocksize)
#
# File /usr/lib/python3.10/ftplib.py:393, in FTP.transfercmd(self, cmd, rest)
#     391 def transfercmd(self, cmd, rest=None):
#     392     """Like ntransfercmd() but returns only the socket."""
# --> 393     return self.ntransfercmd(cmd, rest)[0]
#
# File /usr/lib/python3.10/ftplib.py:354, in FTP.ntransfercmd(self, cmd, rest)
#     352 if self.passiveserver:
#     353     host, port = self.makepasv()
# --> 354     conn = socket.create_connection((host, port), self.timeout,
#     355                                     source_address=self.source_address)
#     356     try:
#     357         if rest is not None:
#
# File /usr/lib/python3.10/socket.py:833, in create_connection(address, timeout, source_address)
#     831 if source_address:
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#     835 err = None
#
# KeyboardInterrupt:

# %%
showProtein(atoms)
legend()

# %%
hetero = atoms.select('not water and not protein')
showProtein(hetero)
# Out:
# <Axes3D: xlabel='x', ylabel='y', zlabel='z'>

# %%
ligands = hetero.getHierView().iterResidues()
list_ligs = []
list_of_ligs = []
for i, residue in enumerate(ligands, start=1):
    list_of_ligs.append(i)
    list_ligs.append(str(residue))
    writePDB(f'{str(best_pdb_id)}_ligand_{i}', residue)

# %%
list_of_ligs
list_ligs
# Out:
# ['IZA 1']

# %%
for i in list_of_ligs:
    run_openbabel(input_file=f'{str(best_pdb_id)}_ligand_{i}.pdb', input_format='pdb', output_file=f'{str(best_pdb_id)}_ligand_{i}.smi', output_format='smi')

# %%
smiles_l = []
for i in list_of_ligs:    
    with open(f'{str(best_pdb_id)}_ligand_{i}.smi', 'r') as file:
        content = file.read()
        smiles, filename = content.split()
        smiles_l.append(smiles)

# %%
smiles_l
# Out:
# ['O=C1N=CCc2c3c(c4c(c12)cc(F)cc4)nc([nH]3)C(C)(C)C']

# %%
smile_dict = dict(zip(list_ligs, smiles_l))
smile_dict
# Out:
# {'IZA 1': 'O=C1N=CCc2c3c(c4c(c12)cc(F)cc4)nc([nH]3)C(C)(C)C'}

# %%
smile_dict.values()
# Out:
# dict_values(['O=C1N=CCc2c3c(c4c(c12)cc(F)cc4)nc([nH]3)C(C)(C)C'])

# %%
data = webScrape("CN1C(=O)[C@H](CC2=CNC3=C2C=CC=C3Cl)NC1=O")
# Out:
# No results for radio button index 2. Moving on...
# No results for radio button index 3. Moving on...
# No results for radio button index 4. Moving on...
# No results for radio button index 5. Moving on...
# No results for radio button index 12. Moving on...
# No results for radio button index 14. Moving on...
# No results for radio button index 15. Moving on...

# %%
df_drugs = pd.DataFrame(data)
df_sorted = df_drugs.sort_values(by='Score', ascending=False)
pd.set_option('display.max_rows', 101)
df_sorted = df_sorted[df_sorted["Score"].astype(float)> 0.7]
df_sorted.head(101)
# Out:
#              Phase           S_method  \
# 536  CHEMBL_clinic   2D & 3D combined
# 537  CHEMBL_clinic   2D & 3D combined
# 84     CHEMBL_drug   2D & 3D combined
# 538  CHEMBL_clinic   2D & 3D combined
# 85     CHEMBL_drug   2D & 3D combined
# 31     CHEMBL_drug  3D - Electroshape
# 32     CHEMBL_drug  3D - Electroshape
# 33     CHEMBL_drug  3D - Electroshape
# 494  CHEMBL_clinic  3D - Electroshape
# 35     CHEMBL_drug  3D - Electroshape
# 36     CHEMBL_drug  3D - Electroshape
# 496  CHEMBL_clinic  3D - Electroshape
# 495  CHEMBL_clinic  3D - Electroshape
# 34     CHEMBL_drug  3D - Electroshape
# 37     CHEMBL_drug  3D - Electroshape
# 498  CHEMBL_clinic  3D - Electroshape
# 497  CHEMBL_clinic  3D - Electroshape
# 38     CHEMBL_drug  3D - Electroshape
# 499  CHEMBL_clinic  3D - Electroshape
# 39     CHEMBL_drug  3D - Electroshape
# 500  CHEMBL_clinic  3D - Electroshape
# 501  CHEMBL_clinic  3D - Electroshape
# 40     CHEMBL_drug  3D - Electroshape
# 502  CHEMBL_clinic  3D - Electroshape
# 43     CHEMBL_drug  3D - Electroshape
# 42     CHEMBL_drug  3D - Electroshape
# 41     CHEMBL_drug  3D - Electroshape
# 44     CHEMBL_drug  3D - Electroshape
# 505  CHEMBL_clinic  3D - Electroshape
# 503  CHEMBL_clinic  3D - Electroshape
# 45     CHEMBL_drug  3D - Electroshape
# 508  CHEMBL_clinic  3D - Electroshape
# 507  CHEMBL_clinic  3D - Electroshape
# 506  CHEMBL_clinic  3D - Electroshape
# 504  CHEMBL_clinic  3D - Electroshape
# 46     CHEMBL_drug  3D - Electroshape
# 48     CHEMBL_drug  3D - Electroshape
# 47     CHEMBL_drug  3D - Electroshape
# 509  CHEMBL_clinic  3D - Electroshape
# 49     CHEMBL_drug  3D - Electroshape
# 510  CHEMBL_clinic  3D - Electroshape
# 50     CHEMBL_drug  3D - Electroshape
# 51     CHEMBL_drug  3D - Electroshape
# 52     CHEMBL_drug  3D - Electroshape
# 54     CHEMBL_drug  3D - Electroshape
# 511  CHEMBL_clinic  3D - Electroshape
# 512  CHEMBL_clinic  3D - Electroshape
# 53     CHEMBL_drug  3D - Electroshape
# 55     CHEMBL_drug  3D - Electroshape
# 513  CHEMBL_clinic  3D - Electroshape
# 56     CHEMBL_drug  3D - Electroshape
# 57     CHEMBL_drug  3D - Electroshape
# 58     CHEMBL_drug  3D - Electroshape
# 514  CHEMBL_clinic  3D - Electroshape
# 515  CHEMBL_clinic  3D - Electroshape
# 59     CHEMBL_drug  3D - Electroshape
# 516  CHEMBL_clinic  3D - Electroshape
# 517  CHEMBL_clinic  3D - Electroshape
# 60     CHEMBL_drug  3D - Electroshape
# 61     CHEMBL_drug  3D - Electroshape
# 518  CHEMBL_clinic  3D - Electroshape
# 519  CHEMBL_clinic  3D - Electroshape
# 62     CHEMBL_drug  3D - Electroshape
# 63     CHEMBL_drug  3D - Electroshape
# 64     CHEMBL_drug  3D - Electroshape
# 520  CHEMBL_clinic  3D - Electroshape
# 65     CHEMBL_drug  3D - Electroshape
# 66     CHEMBL_drug  3D - Electroshape
# 67     CHEMBL_drug  3D - Electroshape
# 68     CHEMBL_drug  3D - Electroshape
# 521  CHEMBL_clinic  3D - Electroshape
# 522  CHEMBL_clinic  3D - Electroshape
# 71     CHEMBL_drug  3D - Electroshape
# 70     CHEMBL_drug  3D - Electroshape
# 69     CHEMBL_drug  3D - Electroshape
# 72     CHEMBL_drug  3D - Electroshape
# 73     CHEMBL_drug  3D - Electroshape
# 523  CHEMBL_clinic  3D - Electroshape
# 74     CHEMBL_drug  3D - Electroshape
# 75     CHEMBL_drug  3D - Electroshape
# 524  CHEMBL_clinic  3D - Electroshape
# 525  CHEMBL_clinic  3D - Electroshape
# 528  CHEMBL_clinic  3D - Electroshape
# 527  CHEMBL_clinic  3D - Electroshape
# 526  CHEMBL_clinic  3D - Electroshape
# 76     CHEMBL_drug  3D - Electroshape
# 529  CHEMBL_clinic  3D - Electroshape
# 530  CHEMBL_clinic  3D - Electroshape
# 531  CHEMBL_clinic  3D - Electroshape
# 77     CHEMBL_drug  3D - Electroshape
# 87     CHEMBL_drug   2D & 3D combined
# 86     CHEMBL_drug   2D & 3D combined
# 539  CHEMBL_clinic   2D & 3D combined
# 493  CHEMBL_clinic           2D - ErG
# 88     CHEMBL_drug   2D & 3D combined
# 540  CHEMBL_clinic   2D & 3D combined
# 541  CHEMBL_clinic   2D & 3D combined
# 89     CHEMBL_drug   2D & 3D combined
# 90     CHEMBL_drug   2D & 3D combined
# 542  CHEMBL_clinic   2D & 3D combined
# 543  CHEMBL_clinic   2D & 3D combined
#
#                                            SMILES_data    Molecule_ID  Score
# 536                  FC1=CC=C2NC=C(C3CC(=O)NC3=O)C2=C1  CHEMBL4086143  0.965
# 537                  FC1=CC=C2NC=C(C3CC(=O)NC3=O)C2=C1  CHEMBL2103882  0.951
# 84                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C
# 528            CC1(CCCC2=CC(=O)OC3=C2C(=O)NC(=O)N3)CC1  CHEMBL4086143  0.832
# 527            CC1(CCCC2=CC(=O)OC3=C2C(=O)NC(=O)N3)CC1  CHEMBL3989444  0.832
# 526            CC1(CCCC2=CC(=O)OC3=C2C(=O)NC(=O)N3)CC1  CHEMBL2036958  0.832
# 76                       CCCC(C)C1(CC)C(=O)NC(=O)NC1=O       CHEMBL42  0.831
# 529            CC1(CCCC2=CC(=O)OC3=C2C(=O)NC(=O)N3)CC1  CHEMBL4594381  0.831
# 530               CC1(C)CCC2=C(O1)C1=CC=CC=C1C(=O)C2=O    CHEMBL15192  0.831
# 531               CC1(C)CCC2=C(O1)C1=CC=CC=C1C(=O)C2=O  CHEMBL4650348  0.831
# 77                       CCCC(C)C1(CC)C(=O)NC(=O)NC1=O      CHEMBL454  0.830
# 87                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1       CHEMBL16  0.806
# 86                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1     CHEMBL1611  0.806
# 539                  FC1=CC=C2NC=C(C3CC(=O)NC3=O)C2=C1  CHEMBL2158685  0.791
# 493                  FC1=CC=C2NC=C(C3CC(=O)NC3=O)C2=C1  CHEMBL4086143  0.781
# 88                        CCC(C(=O)NC(N)=O)C1=CC=CC=C1  CHEMBL2107062  0.770
# 540  C[C@H]1CC2=C(NC3=CC(Cl)=C(F)C=C23)[C@@]2(N1)C(...  CHEMBL1082723  0.756
# 541  C[C@H]1CC2=C(NC3=CC(Cl)=C(F)C=C23)[C@@]2(N1)C(...  CHEMBL4297523  0.751
# 89                        CCC(C(=O)NC(N)=O)C1=CC=CC=C1     CHEMBL1095  0.749
# 90                        CCC(C(=O)NC(N)=O)C1=CC=CC=C1      CHEMBL856  0.746
# 542  C[C@H]1CC2=C(NC3=CC(Cl)=C(F)C=C23)[C@@]2(N1)C(...  CHEMBL1643895  0.742
# 543  C[C@H]1CC2=C(NC3=CC(Cl)=C(F)C=C23)[C@@]2(N1)C(...  CHEMBL3181841  0.727

# %%
ser_chem = nc.new_client.molecule

# %%
list_pref_names = []
for i in df_sorted["Molecule_ID"].to_list():
    
    m1 = ser_chem.filter(chembl_id=i).only(['pref_name'])
    list_pref_names.append(m1[0]['pref_name'])

df_sorted['pref_names'] = list_pref_names
df_sorted
# Out:
#              Phase           S_method  \
# 536  CHEMBL_clinic   2D & 3D combined
# 537  CHEMBL_clinic   2D & 3D combined
# 84     CHEMBL_drug   2D & 3D combined
# 538  CHEMBL_clinic   2D & 3D combined
# 85     CHEMBL_drug   2D & 3D combined
# 31     CHEMBL_drug  3D - Electroshape
# 32     CHEMBL_drug  3D - Electroshape
# 33     CHEMBL_drug  3D - Electroshape
# 494  CHEMBL_clinic  3D - Electroshape
# 35     CHEMBL_drug  3D - Electroshape
# 36     CHEMBL_drug  3D - Electroshape
# 496  CHEMBL_clinic  3D - Electroshape
# 495  CHEMBL_clinic  3D - Electroshape
# 34     CHEMBL_drug  3D - Electroshape
# 37     CHEMBL_drug  3D - Electroshape
# 498  CHEMBL_clinic  3D - Electroshape
# 497  CHEMBL_clinic  3D - Electroshape
# 38     CHEMBL_drug  3D - Electroshape
# 499  CHEMBL_clinic  3D - Electroshape
# 39     CHEMBL_drug  3D - Electroshape
# 500  CHEMBL_clinic  3D - Electroshape
# 501  CHEMBL_clinic  3D - Electroshape
# 40     CHEMBL_drug  3D - Electroshape
# 502  CHEMBL_clinic  3D - Electroshape
# 43     CHEMBL_drug  3D - Electroshape
# 42     CHEMBL_drug  3D - Electroshape
# 41     CHEMBL_drug  3D - Electroshape
# 44     CHEMBL_drug  3D - Electroshape
# 505  CHEMBL_clinic  3D - Electroshape
# 503  CHEMBL_clinic  3D - Electroshape
# 45     CHEMBL_drug  3D - Electroshape
# 508  CHEMBL_clinic  3D - Electroshape
# 507  CHEMBL_clinic  3D - Electroshape
# 506  CHEMBL_clinic  3D - Electroshape
# 504  CHEMBL_clinic  3D - Electroshape
# 46     CHEMBL_drug  3D - Electroshape
# 48     CHEMBL_drug  3D - Electroshape
# 47     CHEMBL_drug  3D - Electroshape
# 509  CHEMBL_clinic  3D - Electroshape
# 49     CHEMBL_drug  3D - Electroshape
# 510  CHEMBL_clinic  3D - Electroshape
# 50     CHEMBL_drug  3D - Electroshape
# 51     CHEMBL_drug  3D - Electroshape
# 52     CHEMBL_drug  3D - Electroshape
# 54     CHEMBL_drug  3D - Electroshape
# 511  CHEMBL_clinic  3D - Electroshape
# 512  CHEMBL_clinic  3D - Electroshape
# 53     CHEMBL_drug  3D - Electroshape
# 55     CHEMBL_drug  3D - Electroshape
# 513  CHEMBL_clinic  3D - Electroshape
# 56     CHEMBL_drug  3D - Electroshape
# 57     CHEMBL_drug  3D - Electroshape
# 58     CHEMBL_drug  3D - Electroshape
# 514  CHEMBL_clinic  3D - Electroshape
# 515  CHEMBL_clinic  3D - Electroshape
# 59     CHEMBL_drug  3D - Electroshape
# 516  CHEMBL_clinic  3D - Electroshape
# 517  CHEMBL_clinic  3D - Electroshape
# 60     CHEMBL_drug  3D - Electroshape
# 61     CHEMBL_drug  3D - Electroshape
# 518  CHEMBL_clinic  3D - Electroshape
# 519  CHEMBL_clinic  3D - Electroshape
# 62     CHEMBL_drug  3D - Electroshape
# 63     CHEMBL_drug  3D - Electroshape
# 64     CHEMBL_drug  3D - Electroshape
# 520  CHEMBL_clinic  3D - Electroshape
# 65     CHEMBL_drug  3D - Electroshape
# 66     CHEMBL_drug  3D - Electroshape
# 67     CHEMBL_drug  3D - Electroshape
# 68     CHEMBL_drug  3D - Electroshape
# 521  CHEMBL_clinic  3D - Electroshape
# 522  CHEMBL_clinic  3D - Electroshape
# 71     CHEMBL_drug  3D - Electroshape
# 70     CHEMBL_drug  3D - Electroshape
# 69     CHEMBL_drug  3D - Electroshape
# 72     CHEMBL_drug  3D - Electroshape
# 73     CHEMBL_drug  3D - Electroshape
# 523  CHEMBL_clinic  3D - Electroshape
# 74     CHEMBL_drug  3D - Electroshape
# 75     CHEMBL_drug  3D - Electroshape
# 524  CHEMBL_clinic  3D - Electroshape
# 525  CHEMBL_clinic  3D - Electroshape
# 528  CHEMBL_clinic  3D - Electroshape
# 527  CHEMBL_clinic  3D - Electroshape
# 526  CHEMBL_clinic  3D - Electroshape
# 76     CHEMBL_drug  3D - Electroshape
# 529  CHEMBL_clinic  3D - Electroshape
# 530  CHEMBL_clinic  3D - Electroshape
# 531  CHEMBL_clinic  3D - Electroshape
# 77     CHEMBL_drug  3D - Electroshape
# 87     CHEMBL_drug   2D & 3D combined
# 86     CHEMBL_drug   2D & 3D combined
# 539  CHEMBL_clinic   2D & 3D combined
# 493  CHEMBL_clinic           2D - ErG
# 88     CHEMBL_drug   2D & 3D combined
# 540  CHEMBL_clinic   2D & 3D combined
# 541  CHEMBL_clinic   2D & 3D combined
# 89     CHEMBL_drug   2D & 3D combined
# 90     CHEMBL_drug   2D & 3D combined
# 542  CHEMBL_clinic   2D & 3D combined
# 543  CHEMBL_clinic   2D & 3D combined
#
#                                            SMILES_data    Molecule_ID  Score  \
# 536                  FC1=CC=C2NC=C(C3CC(=O)NC3=O)C2=C1  CHEMBL4086143  0.965
# 537                  FC1=CC=C2NC=C(C3CC(=O)NC3=O)C2=C1  CHEMBL2103882  0.951
# 84                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1      CHEMBL861  0.920
# 538                  FC1=CC=C2NC=C(C3CC(=O)NC3=O)C2=C1    CHEMBL49642  0.908
# 85                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1       CHEMBL45  0.902
# 31                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1      CHEMBL861  0.885
# 32                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1  CHEMBL3137320  0.881
# 33                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1       CHEMBL45  0.880
# 494                    CC1=CC=CC(C)=C1NC(=O)CN1CCCC1=O   CHEMBL260829  0.880
# 35             O=C1NC(=O)C(N1)(C1=CC=CC=C1)C1=CC=CC=C1     CHEMBL1611  0.870
# 36             O=C1NC(=O)C(N1)(C1=CC=CC=C1)C1=CC=CC=C1       CHEMBL16  0.870
# 496                    CC1=CC=CC(C)=C1NC(=O)CN1CCCC1=O  CHEMBL2107309  0.870
# 495                    CC1=CC=CC(C)=C1NC(=O)CN1CCCC1=O  CHEMBL2111081  0.870
# 34                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1  CHEMBL1079604  0.870
# 37             O=C1NC(=O)C(N1)(C1=CC=CC=C1)C1=CC=CC=C1  CHEMBL3137318  0.869
# 498        COC1=CC=C2NC=C(CCNC(=O)C3=CC(=O)C=CO3)C2=C1  CHEMBL4297523  0.867
# 497                    CC1=CC=CC(C)=C1NC(=O)CN1CCCC1=O  CHEMBL4298138  0.867
# 38             O=C1NC(=O)C(N1)(C1=CC=CC=C1)C1=CC=CC=C1  CHEMBL1083385  0.866
# 499        COC1=CC=C2NC=C(CCNC(=O)C3=CC(=O)C=CO3)C2=C1  CHEMBL1082723  0.866
# 39   CN1C2=CC=C(Cl)C=C2C2(OC(C)=CC(=O)N2CC1=O)C1=CC...  CHEMBL2104356  0.865
# 500        COC1=CC=C2NC=C(CCNC(=O)C3=CC(=O)C=CO3)C2=C1   CHEMBL430488  0.865
# 501        COC1=CC=C2NC=C(CCNC(=O)C3=CC(=O)C=CO3)C2=C1  CHEMBL2272076  0.865
# 71                   O=S1(=O)CCN(CN2CCS(=O)(=O)NC2)CN1  CHEMBL2105420  0.836
# 70        CN(CS(O)(=O)=O)C1=C(C)N(C)N(C1=O)C1=CC=CC=C1  CHEMBL1201773  0.836
# 69        CN(CS(O)(=O)=O)C1=C(C)N(C)N(C1=O)C1=CC=CC=C1  CHEMBL1795071  0.836
# 72                   O=S1(=O)CCN(CN2CCS(=O)(=O)NC2)CN1  CHEMBL1201772  0.836
# 73                   O=S1(=O)CCN(CN2CCS(=O)(=O)NC2)CN1  CHEMBL1789941  0.835
# 523  CCOC1=NC=C(C)C2=C1[C@H](C1=CC=C(C=C1OC)C#N)C(C...    CHEMBL49642  0.835
# 74                   O=S1(=O)CCN(CN2CCS(=O)(=O)NC2)CN1      CHEMBL448  0.834
# 75                       CCCC(C)C1(CC)C(=O)NC(=O)NC1=O      CHEMBL971  0.834
# 524  CCOC1=NC=C(C)C2=C1[C@H](C1=CC=C(C=C1OC)C#N)C(C...       CHEMBL63  0.833
# 525  CCOC1=NC=C(C)C2=C1[C@H](C1=CC=C(C=C1OC)C#N)C(C...  CHEMBL4650334  0.833
# 528            CC1(CCCC2=CC(=O)OC3=C2C(=O)NC(=O)N3)CC1  CHEMBL4086143  0.832
# 527            CC1(CCCC2=CC(=O)OC3=C2C(=O)NC(=O)N3)CC1  CHEMBL3989444  0.832
# 526            CC1(CCCC2=CC(=O)OC3=C2C(=O)NC(=O)N3)CC1  CHEMBL2036958  0.832
# 76                       CCCC(C)C1(CC)C(=O)NC(=O)NC1=O       CHEMBL42  0.831
# 529            CC1(CCCC2=CC(=O)OC3=C2C(=O)NC(=O)N3)CC1  CHEMBL4594381  0.831
# 530               CC1(C)CCC2=C(O1)C1=CC=CC=C1C(=O)C2=O    CHEMBL15192  0.831
# 531               CC1(C)CCC2=C(O1)C1=CC=CC=C1C(=O)C2=O  CHEMBL4650348  0.831
# 77                       CCCC(C)C1(CC)C(=O)NC(=O)NC1=O      CHEMBL454  0.830
# 87                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1       CHEMBL16  0.806
# 86                     CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1     CHEMBL1611  0.806
# 539                  FC1=CC=C2NC=C(C3CC(=O)NC3=O)C2=C1  CHEMBL2158685  0.791
# 493                  FC1=CC=C2NC=C(C3CC(=O)NC3=O)C2=C1  CHEMBL4086143  0.781
# 88                        CCC(C(=O)NC(N)=O)C1=CC=CC=C1  CHEMBL2107062  0.770
# 540  C[C@H]1CC2=C(NC3=CC(Cl)=C(F)C=C23)[C@@]2(N1)C(...  CHEMBL1082723  0.756
# 541  C[C@H]1CC2=C(NC3=CC(Cl)=C(F)C=C23)[C@@]2(N1)C(...  CHEMBL4297523  0.751
# 89                        CCC(C(=O)NC(N)=O)C1=CC=CC=C1     CHEMBL1095  0.749
# 90                        CCC(C(=O)NC(N)=O)C1=CC=CC=C1      CHEMBL856  0.746
# 542  C[C@H]1CC2=C(NC3=CC(Cl)=C(F)C=C23)[C@@]2(N1)C(...  CHEMBL1643895  0.742
# 543  C[C@H]1CC2=C(NC3=CC(Cl)=C(F)C=C23)[C@@]2(N1)C(...  CHEMBL3181841  0.727
#
#                          pref_names
# 536                     PF-06840003
# 537                      TIVANTINIB
# 84                      MEPHENYTOIN
# 538                       INDIBULIN
# 85                        MELATONIN
# 31                      MEPHENYTOIN
# 32                      TALAZOPARIB
# 33                        MELATONIN
# 494                     NEFIRACETAM
# 35                 PHENYTOIN SODIUM
# 36                        PHENYTOIN
# 496             ALAGEBRIUM CHLORIDE
# 495                      ALAGEBRIUM
# 34                       METAXALONE
# 37             TALAZOPARIB TOSYLATE
# 498                    PIROMELATINE
# 497                   REPOTRECTINIB
# 38            CLOPIDOGREL BISULFATE
# 499                      CIPARGAMIN
# 39                        KETAZOLAM
# 500                     TALVIRALINE
# 501                     TOPRAMEZONE
# 40                    FLUNITRAZEPAM
# 502                     ROVATIRELIN
# 43                     NITRENDIPINE
# 42                    CHLORMEZANONE
# 41                       FLUMAZENIL
# 44                      TASIMELTEON
# 505               NAPROXEN ETEMESIL
# 503                    OLUTASIDENIB
# 45                     PROPYLIODONE
# 508                    NELOTANSERIN
# 507                         FENOBAM
# 506                         FENOBAM
# 504                     GSK-2556286
# 46                       OLANZAPINE
# 48                     BENZNIDAZOLE
# 47                     GLUTETHIMIDE
# 509              ANTINEOPLASTON A10
# 49                       NABUMETONE
# 510                   SELITRECTINIB
# 50                      AGOMELATINE
# 51               AMOBARBITAL SODIUM
# 52                      AMOBARBITAL
# 54                      CLOPIDOGREL
# 511                     NILVADIPINE
# 512                      MAVACAMTEN
# 53                        PRIMIDONE
# 55                      REMIMAZOLAM
# 513                       PAMIPARIB
# 56                       NITRAZEPAM
# 57                    OXCARBAZEPINE
# 58                        BECLAMIDE
# 514                       ADIPIPLON
# 515                         KL-1333
# 59                       CLONAZEPAM
# 516                       IOMAZENIL
# 517                    FEZOLINETANT
# 60                        ENOXIMONE
# 61                      PHENETURIDE
# 518                         CI-1040
# 519                       SEMUSTINE
# 62                       NEVIRAPINE
# 63   CHLORDIAZEPOXIDE HYDROCHLORIDE
# 64                 CHLORDIAZEPOXIDE
# 520             TEPILAMIDE FUMARATE
# 65                         DIPYRONE
# 66                     METHOHEXITAL
# 67                         DIPYRONE
# 68              METHOHEXITAL SODIUM
# 521                      TIVANTINIB
# 522                      FINERENONE
# 71                      TAUROLIDINE
# 70          PRASUGREL HYDROCHLORIDE
# 69            RUXOLITINIB PHOSPHATE
# 72                        PRASUGREL
# 73                      RUXOLITINIB
# 523                       INDIBULIN
# 74                    PENTOBARBITAL
# 75             PENTOBARBITAL SODIUM
# 524                        ROLIPRAM
# 525                      ALDUMASTAT
# 528                     PF-06840003
# 527                       VISNADINE
# 526                      SCH-900271
# 76                        CLOZAPINE
# 529                  DEURUXOLITINIB
# 530                       LAPACHONE
# 531               BENZOYLPHENYLUREA
# 77                       BUTALBITAL
# 87                        PHENYTOIN
# 86                 PHENYTOIN SODIUM
# 539                      ABC-294640
# 493                     PF-06840003
# 88                      PHENETURIDE
# 540                      CIPARGAMIN
# 541                    PIROMELATINE
# 89                         ETHOTOIN
# 90                        PRIMIDONE
# 542                      RAMOSETRON
# 543        RAMOSETRON HYDROCHLORIDE

# %%
drug_df = df_sorted[df_sorted['Phase'] == "CHEMBL_drug"]
pd.set_option('display.max_colwidth', None) 
PandasTools.AddMoleculeColumnToFrame(drug_df, smilesCol="SMILES_data")
drug_df
# Out:
# /home/raminrafiee/Desktop/personal/projects/automatedDrugrepurpose/venv/lib/python3.10/site-packages/rdkit/Chem/PandasTools.py:371: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(Chem.MolFromSmiles)
# /home/raminrafiee/Desktop/personal/projects/automatedDrugrepurpose/venv/lib/python3.10/site-packages/rdkit/Chem/PandasPatcher.py:132: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   for col in df_subset.columns[df_subset.applymap(MolFormatter.is_mol).any()]
#           Phase           S_method  \
# 84  CHEMBL_drug   2D & 3D combined
# 85  CHEMBL_drug   2D & 3D combined
# 31  CHEMBL_drug  3D - Electroshape
# 32  CHEMBL_drug  3D - Electroshape
# 33  CHEMBL_drug  3D - Electroshape
# 35  CHEMBL_drug  3D - Electroshape
# 36  CHEMBL_drug  3D - Electroshape
# 34  CHEMBL_drug  3D - Electroshape
# 37  CHEMBL_drug  3D - Electroshape
# 38  CHEMBL_drug  3D - Electroshape
# 39  CHEMBL_drug  3D - Electroshape
# 40  CHEMBL_drug  3D - Electroshape
# 43  CHEMBL_drug  3D - Electroshape
# 42  CHEMBL_drug  3D - Electroshape
# 41  CHEMBL_drug  3D - Electroshape
# 44  CHEMBL_drug  3D - Electroshape
# 45  CHEMBL_drug  3D - Electroshape
# 46  CHEMBL_drug  3D - Electroshape
# 48  CHEMBL_drug  3D - Electroshape
# 47  CHEMBL_drug  3D - Electroshape
# 49  CHEMBL_drug  3D - Electroshape
# 50  CHEMBL_drug  3D - Electroshape
# 51  CHEMBL_drug  3D - Electroshape
# 52  CHEMBL_drug  3D - Electroshape
# 54  CHEMBL_drug  3D - Electroshape
# 53  CHEMBL_drug  3D - Electroshape
# 55  CHEMBL_drug  3D - Electroshape
# 56  CHEMBL_drug  3D - Electroshape
# 57  CHEMBL_drug  3D - Electroshape
# 58  CHEMBL_drug  3D - Electroshape
# 59  CHEMBL_drug  3D - Electroshape
# 60  CHEMBL_drug  3D - Electroshape
# 61  CHEMBL_drug  3D - Electroshape
# 62  CHEMBL_drug  3D - Electroshape
# 63  CHEMBL_drug  3D - Electroshape
# 64  CHEMBL_drug  3D - Electroshape
# 65  CHEMBL_drug  3D - Electroshape
# 66  CHEMBL_drug  3D - Electroshape
# 67  CHEMBL_drug  3D - Electroshape
# 68  CHEMBL_drug  3D - Electroshape
# 71  CHEMBL_drug  3D - Electroshape
# 70  CHEMBL_drug  3D - Electroshape
# 69  CHEMBL_drug  3D - Electroshape
# 72  CHEMBL_drug  3D - Electroshape
# 73  CHEMBL_drug  3D - Electroshape
# 74  CHEMBL_drug  3D - Electroshape
# 75  CHEMBL_drug  3D - Electroshape
# 76  CHEMBL_drug  3D - Electroshape
# 77  CHEMBL_drug  3D - Electroshape
# 87  CHEMBL_drug   2D & 3D combined
# 86  CHEMBL_drug   2D & 3D combined
# 88  CHEMBL_drug   2D & 3D combined
# 89  CHEMBL_drug   2D & 3D combined
# 90  CHEMBL_drug   2D & 3D combined
#
#                                                      SMILES_data  \
# 84                               CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C
# 61            [O-][N+](=O)C1=CC=C2NC(=O)CN=C(C3=CC=CC=C3Cl)C2=C1
# 62            [O-][N+](=O)C1=CC=C2NC(=O)CN=C(C3=CC=CC=C3Cl)C2=C1
# 63              CN=C1C[N+]([O-])=C(C2=CC=CC=C2)C2=CC(Cl)=CC=C2N1
# 64              CN=C1C[N+]([O-])=C(C2=CC=CC=C2)C2=CC(Cl)=CC=C2N1
# 65              CN=C1C[N+]([O-])=C(C2=CC=CC=C2)C2=CC(Cl)=CC=C2N1
# 66              CN=C1C[N+]([O-])=C(C2=CC=CC=C2)C2=CC(Cl)=CC=C2N1
# 67                  CN(CS(O)(=O)=O)C1=C(C)N(C)N(C1=O)C1=CC=CC=C1
# 68                  CN(CS(O)(=O)=O)C1=C(C)N(C)N(C1=O)C1=CC=CC=C1
# 71                             O=S1(=O)CCN(CN2CCS(=O)(=O)NC2)CN1
# 70                  CN(CS(O)(=O)=O)C1=C(C)N(C)N(C1=O)C1=CC=CC=C1
# 69                  CN(CS(O)(=O)=O)C1=C(C)N(C)N(C1=O)C1=CC=CC=C1
# 72                             O=S1(=O)CCN(CN2CCS(=O)(=O)NC2)CN1
# 73                             O=S1(=O)CCN(CN2CCS(=O)(=O)NC2)CN1
# 74                             O=S1(=O)CCN(CN2CCS(=O)(=O)NC2)CN1
# 75                                 CCCC(C)C1(CC)C(=O)NC(=O)NC1=O
# 76                                 CCCC(C)C1(CC)C(=O)NC(=O)NC1=O
# 77                                 CCCC(C)C1(CC)C(=O)NC(=O)NC1=O
# 87                               CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1
# 86                               CCC1(NC(=O)N(C)C1=O)C1=CC=CC=C1
# 88                                  CCC(C(=O)NC(N)=O)C1=CC=CC=C1
# 89                                  CCC(C(=O)NC(N)=O)C1=CC=CC=C1
# 90                                  CCC(C(=O)NC(N)=O)C1=CC=CC=C1
#
#       Molecule_ID  Score                      pref_names  \
# 84      CHEMBL861  0.920                     MEPHENYTOIN
# 85       CHEMBL45  0.902                       MELATONIN
# 31      CHEMBL861  0.885                     MEPHENYTOIN
# 32  CHEMBL3137320  0.881                     TALAZOPARIB
# 33       CHEMBL45  0.880                       MELATONIN
# 35     CHEMBL1611  0.870                PHENYTOIN SODIUM
# 36       CHEMBL16  0.870                       PHENYTOIN
# 34  CHEMBL1079604  0.870                      METAXALONE
# 37  CHEMBL3137318  0.869            TALAZOPARIB TOSYLATE
# 38  CHEMBL1083385  0.866           CLOPIDOGREL BISULFATE
# 39  CHEMBL2104356  0.865                       KETAZOLAM
# 40    CHEMBL13280  0.864                   FLUNITRAZEPAM
# 43   CHEMBL475534  0.860                    NITRENDIPINE
# 42  CHEMBL1200714  0.860                   CHLORMEZANONE
# 41      CHEMBL407  0.860                      FLUMAZENIL
# 44  CHEMBL2103822  0.859                     TASIMELTEON
# 45  CHEMBL1200821  0.857                    PROPYLIODONE
# 46      CHEMBL715  0.856                      OLANZAPINE
# 48      CHEMBL110  0.855                    BENZNIDAZOLE
# 47     CHEMBL1102  0.855                    GLUTETHIMIDE
# 49     CHEMBL1070  0.853                      NABUMETONE
# 50    CHEMBL10878  0.848                     AGOMELATINE
# 51  CHEMBL2105941  0.848              AMOBARBITAL SODIUM
# 52   CHEMBL267894  0.848                     AMOBARBITAL
# 54     CHEMBL1771  0.847                     CLOPIDOGREL
# 53      CHEMBL856  0.847                       PRIMIDONE
# 55  CHEMBL4297526  0.846                     REMIMAZOLAM
# 56    CHEMBL13209  0.845                      NITRAZEPAM
# 57     CHEMBL1068  0.845                   OXCARBAZEPINE
# 58    CHEMBL64195  0.845                       BECLAMIDE
# 59      CHEMBL452  0.844                      CLONAZEPAM
# 60   CHEMBL249856  0.840                       ENOXIMONE
# 61  CHEMBL2107062  0.840                     PHENETURIDE
# 62       CHEMBL57  0.838                      NEVIRAPINE
# 63  CHEMBL1200703  0.838  CHLORDIAZEPOXIDE HYDROCHLORIDE
# 64      CHEMBL451  0.838                CHLORDIAZEPOXIDE
# 65  CHEMBL3989803  0.837                        DIPYRONE
# 66     CHEMBL7413  0.837                    METHOHEXITAL
# 67   CHEMBL461522  0.837                        DIPYRONE
# 68    CHEMBL30219  0.837             METHOHEXITAL SODIUM
# 71  CHEMBL2105420  0.836                     TAUROLIDINE
# 70  CHEMBL1201773  0.836         PRASUGREL HYDROCHLORIDE
# 69  CHEMBL1795071  0.836           RUXOLITINIB PHOSPHATE
# 72  CHEMBL1201772  0.836                       PRASUGREL
# 73  CHEMBL1789941  0.835                     RUXOLITINIB
# 74      CHEMBL448  0.834                   PENTOBARBITAL
# 75      CHEMBL971  0.834            PENTOBARBITAL SODIUM
# 76       CHEMBL42  0.831                       CLOZAPINE
# 77      CHEMBL454  0.830                      BUTALBITAL
# 87       CHEMBL16  0.806                       PHENYTOIN
# 86     CHEMBL1611  0.806                PHENYTOIN SODIUM
# 88  CHEMBL2107062  0.770                     PHENETURIDE
# 89     CHEMBL1095  0.749                        ETHOTOIN
# 90      CHEMBL856  0.746                       PRIMIDONE
#
#                                                ROMol
# 84  <rdkit.Chem.rdchem.Mol object at 0x759514ecf4c0>
# 85  <rdkit.Chem.rdchem.Mol object at 0x759514ecf290>
# 31  <rdkit.Chem.rdchem.Mol object at 0x759514ecc5f0>
# 32  <rdkit.Chem.rdchem.Mol object at 0x759514ecf300>
# 33  <rdkit.Chem.rdchem.Mol object at 0x759514ecf450>
# 35  <rdkit.Chem.rdchem.Mol object at 0x759514ecc970>
# 36  <rdkit.Chem.rdchem.Mol object at 0x759514ecca50>
# 34  <rdkit.Chem.rdchem.Mol object at 0x759514ecdbd0>
# 37  <rdkit.Chem.rdchem.Mol object at 0x759514ecf1b0>
# 38  <rdkit.Chem.rdchem.Mol object at 0x759514ecf140>
# 39  <rdkit.Chem.rdchem.Mol object at 0x759514ecc6d0>
# 40  <rdkit.Chem.rdchem.Mol object at 0x759514ecd690>
# 43  <rdkit.Chem.rdchem.Mol object at 0x759514ecfe60>
# 42  <rdkit.Chem.rdchem.Mol object at 0x759514ecfd80>
# 41  <rdkit.Chem.rdchem.Mol object at 0x759514ecfdf0>
# 44  <rdkit.Chem.rdchem.Mol object at 0x759514ecfd10>
# 45  <rdkit.Chem.rdchem.Mol object at 0x759514ecfbc0>
# 46  <rdkit.Chem.rdchem.Mol object at 0x759514ecf990>
# 48  <rdkit.Chem.rdchem.Mol object at 0x759514ecf8b0>
# 47  <rdkit.Chem.rdchem.Mol object at 0x759514ecfc30>
# 49  <rdkit.Chem.rdchem.Mol object at 0x759514ecf840>
# 50  <rdkit.Chem.rdchem.Mol object at 0x759514ecde00>
# 51  <rdkit.Chem.rdchem.Mol object at 0x759514ecdf50>
# 52  <rdkit.Chem.rdchem.Mol object at 0x759514ecdfc0>
# 54  <rdkit.Chem.rdchem.Mol object at 0x759514eccdd0>
# 53  <rdkit.Chem.rdchem.Mol object at 0x759514eccf20>
# 55  <rdkit.Chem.rdchem.Mol object at 0x759514ecd230>
# 56  <rdkit.Chem.rdchem.Mol object at 0x759514eb1460>
# 57  <rdkit.Chem.rdchem.Mol object at 0x759514eb1070>
# 58  <rdkit.Chem.rdchem.Mol object at 0x759514eb17e0>
# 59  <rdkit.Chem.rdchem.Mol object at 0x759514eb31b0>
# 60  <rdkit.Chem.rdchem.Mol object at 0x759514eb3370>
# 61  <rdkit.Chem.rdchem.Mol object at 0x759514eb10e0>
# 62  <rdkit.Chem.rdchem.Mol object at 0x759514eb1310>
# 63  <rdkit.Chem.rdchem.Mol object at 0x759514eb3450>
# 64  <rdkit.Chem.rdchem.Mol object at 0x759514eb11c0>
# 65  <rdkit.Chem.rdchem.Mol object at 0x759514edcac0>
# 66  <rdkit.Chem.rdchem.Mol object at 0x759514edc890>
# 67  <rdkit.Chem.rdchem.Mol object at 0x759514edc970>
# 68  <rdkit.Chem.rdchem.Mol object at 0x759514edc900>
# 71  <rdkit.Chem.rdchem.Mol object at 0x759514edc7b0>
# 70  <rdkit.Chem.rdchem.Mol object at 0x759514edc740>
# 69  <rdkit.Chem.rdchem.Mol object at 0x759514edc040>
# 72  <rdkit.Chem.rdchem.Mol object at 0x759514edc0b0>
# 73  <rdkit.Chem.rdchem.Mol object at 0x759514edc120>
# 74  <rdkit.Chem.rdchem.Mol object at 0x759514edc190>
# 75  <rdkit.Chem.rdchem.Mol object at 0x759514edc200>
# 76  <rdkit.Chem.rdchem.Mol object at 0x759514edc270>
# 77  <rdkit.Chem.rdchem.Mol object at 0x759514edc2e0>
# 87  <rdkit.Chem.rdchem.Mol object at 0x759514edc350>
# 86  <rdkit.Chem.rdchem.Mol object at 0x759514edc3c0>
# 88  <rdkit.Chem.rdchem.Mol object at 0x759514edc430>
# 89  <rdkit.Chem.rdchem.Mol object at 0x759514edc4a0>
# 90  <rdkit.Chem.rdchem.Mol object at 0x759514edc510>

# %%
mol = Chem.MolFromSmiles('C[C@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@]2(C)[C@@]1(O)C(=O)COP(O)(O)=O')
mol = Chem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)

# Export to PDB
pdb_output = Chem.MolToPDBBlock(mol)
with open("molecule.pdb", "w") as file:
    file.write(pdb_output)
